# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
df=pd.read_csv('/content/drive/MyDrive/Bloood pressure data.csv')
df.head()
# Out:
#    Patient_Number  Level_of_Hemoglobin   Age  BMI Gender  Smoking  \
# 0               1                11.28  34.0   23   Male        0
# 1               2                 9.75  54.0   33   Male        0
# 2               3                10.79  70.0   49   Male        0
# 3               4                11.00  71.0   50   Male        0
# 4               5                14.17  52.0   19   Male        0
#
#    Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# 0              45961                     48071                2
# 1              26106                     25333                3
# 2               9995                     29465                2
# 3              10635                      7439                1
# 4              15619                     49644                2
#
#    Chronic_kidney_disease  Adrenal_and_thyroid_disorders  \
# 0                       1                              1
# 1                       0                              0
# ...

# %%
df.tail()
# Out:
#       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# 1995              26118                     47568                3
# 1996               2572                      8063                3
# 1997              14933                     24753                2
# 1998              18157                     15275                3
# 1999              20729                     30463                1
#
#       Chronic_kidney_disease  Adrenal_and_thyroid_disorders  \
# 1995                       1                              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Patient_Number                 2000 non-null   int64
#  1   Level_of_Hemoglobin            2000 non-null   float64
#  2   Age                            1995 non-null   float64
#  3   BMI                            2000 non-null   int64
#  4   Gender                         2000 non-null   object
#  5   Smoking                        2000 non-null   int64
#  6   Physical_activity              2000 non-null   int64
#  7   salt_content_in_the_diet       2000 non-null   int64
#  8   Level_of_Stress                2000 non-null   int64
#  9   Chronic_kidney_disease         2000 non-null   int64
#  10  Adrenal_and_thyroid_disorders  2000 non-null   int64
#  11  Blood_Pressure_Abnormality     2000 non-null   int64
# dtypes: float64(2), int64(9), object(1)
# ...

# %%
df.isnull()
# Out:
#       Patient_Number  Level_of_Hemoglobin    Age    BMI  Gender  Smoking  \
# 0              False                False  False  False   False    False
# 1              False                False  False  False   False    False
# 2              False                False  False  False   False    False
# 3              False                False  False  False   False    False
# 4              False                False  False  False   False    False
# ...              ...                  ...    ...    ...     ...      ...
# 1995           False                False  False  False   False    False
# 1996           False                False  False  False   False    False
# 1997           False                False  False  False   False    False
# 1998           False                False  False  False   False    False
# 1999           False                False  False  False   False    False
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
df.isnull().sum()
# Out:
# Patient_Number                   0
# Level_of_Hemoglobin              0
# Age                              5
# BMI                              0
# Gender                           0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# Blood_Pressure_Abnormality       0
# dtype: int64

# %%
df=pd.read_csv('/content/drive/MyDrive/Bloood pressure data.csv')
mean_age=df['Age'].mean()
df['Age'].fillna(mean_age,inplace=True)

# %%
df.isnull().sum()
# Out:
# Patient_Number                   0
# Level_of_Hemoglobin              0
# Age                              0
# BMI                              0
# Gender                           0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# Blood_Pressure_Abnormality       0
# dtype: int64

# %%
plt.figure()
plt.hist(df['Age'],bins=10)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
plt.plot(df['BMI'],df['BMI'])
plt.xlabel('x')
plt.ylabel('Y')
plt.title('line plot')
# Out:
# Text(0.5, 1.0, 'line plot')

# %%
columns_to_nomarlize=['Age']
scaler_minmax=MinMaxScaler()
min_max_scaler=MinMaxScaler()
df[columns_to_normalize]=min_max_scaler.fit_transform(df[columns_to_normalize])

# %%
df
# Out:
#       Patient_Number  Level_of_Hemoglobin       Age  BMI  Gender  Smoking  \
# 0                  1                11.28  0.280702   23    Male        0
# 1                  2                 9.75  0.631579   33    Male        0
# 2                  3                10.79  0.912281   49    Male        0
# 3                  4                11.00  0.929825   50    Male        0
# 4                  5                14.17  0.596491   19    Male        0
# ...              ...                  ...       ...  ...     ...      ...
# 1995            1996                10.14  0.894737   26    Male        1
# 1996            1997                11.77  0.105263   45  Female        1
# 1997            1998                16.91  0.000000   42    Male        0
# 1998            1999                11.15  0.491228   45    Male        1
# 1999            2000                11.36  0.403509   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
from scipy import stats
ZScore=stats.zscore(df['BMI'])
ZScore
# Out:
# 0      -0.602257
# 1       0.248208
# 2       1.608953
# 3       1.694000
# 4      -0.942443
#           ...
# 1995   -0.347117
# 1996    1.268767
# 1997    1.013627
# 1998    1.268767
# 1999    1.268767
# Name: BMI, Length: 2000, dtype: float64

# %%
label_encoder=['Gender']

# %%
label_encoder=LabelEncoder()
df['Age_encoder']=label_encoder.fit_transform(df['Gender'])

# %%
df
# Out:
#       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                  1                11.28  34.0   23    Male        0
# 1                  2                 9.75  54.0   33    Male        0
# 2                  3                10.79  70.0   49    Male        0
# 3                  4                11.00  71.0   50    Male        0
# 4                  5                14.17  52.0   19    Male        0
# ...              ...                  ...   ...  ...     ...      ...
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
encoder=OrdinalEncoder()
df['Ordinal_encoding']=encoder.fit_transform(df[['Gender']])

# %%
df
# Out:
#       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                  1                11.28  34.0   23    Male        0
# 1                  2                 9.75  54.0   33    Male        0
# 2                  3                10.79  70.0   49    Male        0
# 3                  4                11.00  71.0   50    Male        0
# 4                  5                14.17  52.0   19    Male        0
# ...              ...                  ...   ...  ...     ...      ...
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...
